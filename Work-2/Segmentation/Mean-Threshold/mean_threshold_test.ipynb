# %%
from mean_threshold import mean_threshold

import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('../../assets/img_test2.png', cv2.IMREAD_COLOR)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(1)
plt.imshow(img_gray, "gray")
plt.title("Original Image")
plt.show()

# %%
img_threshold = mean_threshold(img_gray, 3)

# %%
plt.figure(1)
plt.imshow(img_threshold, "gray")
plt.title("Original Image")
plt.show()

# %%
img_threshold = mean_threshold(img_gray, 5)

# %%
plt.figure(1)
plt.imshow(img_threshold, "gray")
plt.title("Original Image")
plt.show()

# %%
img_threshold = mean_threshold(img_gray, 7)

# %%
plt.figure(1)
plt.imshow(img_threshold, "gray")
plt.title("Original Image")
plt.show()
