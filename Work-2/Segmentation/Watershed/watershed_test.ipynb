# %%
from watershed import watershed_segmentation
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('../../assets/xadrez2.jpg', cv2.IMREAD_COLOR)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(1)
plt.imshow(img_gray, "gray")
plt.title("Original Image")
plt.show()

# %%
img_watershed = watershed_segmentation(img)

# %%
plt.figure(1)
plt.imshow(cv2.cvtColor(img_watershed, cv2.COLOR_BGR2RGB))
plt.title("Segmentação Watershed")
plt.axis('off')
plt.show()
