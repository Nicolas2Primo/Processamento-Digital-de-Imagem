# %%
import cv2
from laplacian_filter import LaplacianFilter

# %%
img = cv2.imread('../../img/teste3.png', cv2.IMREAD_GRAYSCALE)
laplacian = LaplacianFilter(img, "lk1")
laplacian.run_test(1)
# Out:
# [[ 1.  1.  1.]
#  [ 1. -8.  1.]
#  [ 1.  1.  1.]]
# FINISHED

# %%
img = cv2.imread('../../img/teste3.png', cv2.IMREAD_GRAYSCALE)
laplacian = LaplacianFilter(img, "lk2")
laplacian.run_test(1)
# Out:
# [[ 0  1  0]
#  [ 1 -4  1]
#  [ 0  1  0]]
# FINISHED
