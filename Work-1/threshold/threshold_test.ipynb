# %%
import cv2
from threshold import Thresholding

# %%
imagem = cv2.imread("../img/ball.png", 0)
limiar = 70
thresholding = Thresholding(imagem, limiar)
thresholding.apply_and_plot(num_iterations=1)
# Out:
# ################################
# Processo finalizado
# Limiar foi aplicado
# ################################
