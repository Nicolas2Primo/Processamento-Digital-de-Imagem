# %%
import cv2
from multithreshold import MultiThresholding

# %%
imagem = cv2.imread("../img/paisagem.png", 0)
multi_thresholds=[170,200, 220]
multi_range=[175, 190]
multithresholding = MultiThresholding(imagem, multi_thresholds, multi_range)
multithresholding.apply_and_plot(num_iterations=1)
# Out:
# ################################
# Processo finalizado
# Multilimiar foi aplicado
# ################################
