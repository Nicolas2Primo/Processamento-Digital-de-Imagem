# %%
import cv2
from gaussian_filter import GaussianFilter

# %% [markdown]
# Filtro da Gaussian com kernel=3x3 e n=1

# %%
img = cv2.imread("../../img/teste.png", 0)

gaussian_k3n1 = GaussianFilter(img, 3)
gaussian_k3n1.run_test(1)
# Out:
# FINISHED

# %% [markdown]
# Filtro da Mediana com kernel=5x5 e n=1

# %%
img = cv2.imread("../../img/teste.png", 0)

gaussian_k5n1 = GaussianFilter(img, 5)
gaussian_k5n1.run_test(1)
# Out:
# FINISHED

# %% [markdown]
# Filtro da Mediana com kernel=11x11 e n=1

# %%
img = cv2.imread("../../img/teste.png", 0)

gaussian_k11n1 = GaussianFilter(img, 11)
gaussian_k11n1.run_test(1)
# Out:
# FINISHED

# %% [markdown]
# Filtro da Mediana com kernel=3x3 e n=3

# %%
img = cv2.imread("../../img/teste2.png", 0)

gaussian_k3n3 = GaussianFilter(img, 3)
gaussian_k3n3.run_test(3)
# Out:
# FINISHED
# FINISHED
# FINISHED

# %% [markdown]
# Filtro da Mediana com kernel=3x3 e n=6

# %%
img = cv2.imread("../../img/teste2.png", 0)

gaussian_k3n6 = GaussianFilter(img, 3)
gaussian_k3n6.run_test(6)
# Out:
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED

# %% [markdown]
# Filtro da Mediana com kernel=3 e n=10

# %%
img = cv2.imread("../../img/teste2.png", 0)

gaussian_k3n10 = GaussianFilter(img, 3)
gaussian_k3n10.run_test(10)
# Out:
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED
# FINISHED
